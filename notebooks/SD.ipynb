# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 10791, done.
# remote: Total 10791 (delta 0), reused 0 (delta 0), pack-reused 10791
# Receiving objects: 100% (10791/10791), 23.61 MiB | 25.56 MiB/s, done.
# Resolving deltas: 100% (7546/7546), done.

# %%
# %cd stable-diffusion-webui
# Out:
# /workspaces/codespaces-jupyter/notebooks/stable-diffusion-webui

# %%
# !git status
# Out:
# HEAD detached at 7ca9858
# nothing to commit, working tree clean

# %%
# !pwd
# Out:
# /workspaces/codespaces-jupyter/notebooks/stable-diffusion-webui

# %%
# !git checkout 7ca9858c4c05b67089b095142ff792e07b5962a9
# Out:
# Note: switching to '7ca9858c4c05b67089b095142ff792e07b5962a9'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 7ca9858 removed unused import; now using javascript to watch prompt textarea

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/crowsonkb/k-diffusion.git to /tmp/pip-req-build-xdfq6i6k
#   Running command git clone --filter=blob:none --quiet https://github.com/crowsonkb/k-diffusion.git /tmp/pip-req-build-xdfq6i6k
#   Resolved https://github.com/crowsonkb/k-diffusion.git to commit 60e5042ca0da89c14d1dd59d73883280f8fce991
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/TencentARC/GFPGAN.git (to revision 8d2447a2d918f8eba5a4a01463fd48e45126a379) to /tmp/pip-req-build-3puyo2m6
#   Running command git clone --filter=blob:none --quiet https://github.com/TencentARC/GFPGAN.git /tmp/pip-req-build-3puyo2m6
#   Running command git rev-parse -q --verify 'sha^8d2447a2d918f8eba5a4a01463fd48e45126a379'
#   Running command git fetch -q https://github.com/TencentARC/GFPGAN.git 8d2447a2d918f8eba5a4a01463fd48e45126a379
# ...

# %%
# !mkdir repositories

# %%
# !git clone https://github.com/CompVis/stable-diffusion.git repositories/stable-diffusion
# !git clone https://github.com/CompVis/taming-transformers.git repositories/taming-transformers
# !git clone https://github.com/sczhou/CodeFormer.git repositories/CodeFormer
# !git clone https://github.com/salesforce/BLIP.git repositories/BLIP
# Out:
# Cloning into 'repositories/stable-diffusion'...
# remote: Enumerating objects: 340, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 340 (delta 0), reused 2 (delta 0), pack-reused 332
# Receiving objects: 100% (340/340), 42.65 MiB | 33.24 MiB/s, done.
# Resolving deltas: 100% (112/112), done.
# Cloning into 'repositories/taming-transformers'...
# remote: Enumerating objects: 1339, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 1339 (delta 0), reused 2 (delta 0), pack-reused 1335
# Receiving objects: 100% (1339/1339), 409.77 MiB | 37.36 MiB/s, done.
# Resolving deltas: 100% (278/278), done.
# Cloning into 'repositories/CodeFormer'...
# remote: Enumerating objects: 395, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 395 (delta 125), reused 114 (delta 111), pack-reused 223
# ...

# %%
# !pip install -r repositories/CodeFormer/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.0 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for gdown: filename=gdown-4.5.3-py3-none-any.whl size=14821 sha256=a527aa15cb82a362c0f3f5d742501c12f05c136b79d02d2b74df82d7414d818d
#   Stored in directory: /home/codespace/.cache/pip/wheels/6c/dd/fe/4982475d227ab282a93ee540130e88cd43bb1698131b848d25
# Successfully built gdown
# ...
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
#@title Normal 1.4 model
# get a token from https://huggingface.co/settings/tokens
user_token = "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" #@param {type:"string"}
user_header = f"\"Authorization: Bearer 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\""
# !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /workspaces/codespaces-jupyter/notebooks/stable-diffusion-webui/model.ckpt
# Out:
# --2022-11-17 05:40:53--  https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt
# Resolving huggingface.co (huggingface.co)... 34.200.207.32, 34.227.196.80, 2600:1f18:147f:e800:7a81:37eb:4345:da2, ...
# Connecting to huggingface.co (huggingface.co)|34.200.207.32|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pwd
# Out:
# /workspaces/codespaces-jupyter/notebooks/stable-diffusion-webui

# %%
import sys
sys.argv = ['webui.py', "--share", "--opt-split-attention"]

import webui
webui.webui()
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [14], line 4
#       1 import sys
#       2 sys.argv = ['webui.py', "--share", "--opt-split-attention"]
# ----> 4 import webui
#       5 webui.webui()
#
# File /workspaces/codespaces-jupyter/notebooks/stable-diffusion-webui/webui.py:10
#       8 from modules.shared import opts, cmd_opts, state
#       9 import modules.shared as shared
# ---> 10 import modules.ui
#      11 import modules.scripts
#      12 import modules.sd_hijack
#
# File /workspaces/codespaces-jupyter/notebooks/stable-diffusion-webui/modules/ui.py:26
#      24 from modules.sd_samplers import samplers, samplers_for_img2img
#      25 from modules.sd_hijack import model_hijack
# ---> 26 import modules.ldsr_model
#      27 import modules.scripts
#      28 import modules.gfpgan_model
#
# ...
